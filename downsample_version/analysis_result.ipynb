# %%
import numpy as np
import matplotlib.pyplot as plt
import deepdish as dd

# %%
loss_array = dd.io.load('./model/unet_mse_loss.h5')

# %%
loss_array.shape
# Out:
# (1500, 1)

# %%
plt.plot(loss_array)
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('model loss')
plt.show()
