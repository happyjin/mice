# %%
import numpy as np
import deepdish as dd
import matplotlib.pyplot as plt
from scipy.misc import `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
import h5py

# %% [markdown]
# ### load data

# %%
indices = dd.io.load('clean_labeled_data_indeces.h5')
labels = dd.io.load('clean_labeled_data.h5')
#image_data = dd.io.load('5000_data.h5')

# %%
f = h5py.File('5000_data.h5', 'r')

# List all groups
print("Keys: %s" % f.keys())
a_group_key = list(f.keys())[0]

# Get the data
image_data = list(f[a_group_key])
# Out:
# Keys: KeysView(<HDF5 file "5000_data.h5" (mode r)>)

# %%
len(image_data)
# Out:
# 5000

# %% [markdown]
# ### example data visualization

# %%
i = 0
plt.imshow(image_data[indices[i]].reshape(840, 840))
plt.show()

# %% [markdown]
# ### sample input images

# %%
sample_origional_images = []
size = image_data[0].shape[0]
for _, index in enumerate(indices):
    sample_origional_images.append(image_data[index].reshape(size, size))
sample_origional_images = np.array(sample_origional_images)

# %%
sample_origional_images.shape
# Out:
# (105, 840, 840)

# %%
dd.io.save('sample_origonal_images.h5', sample_origional_images)
